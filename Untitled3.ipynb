# %% [markdown]
# <a href="https://colab.research.google.com/github/nirmitktripathii/Football_Data_analysis_ISL/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
scrapurl = "https://understat.com/league/"
league = input("Enter League: ")
# Out:
# Enter League: EPL

# %%
url = scrapurl+league
url
# Out:
# 'https://understat.com/league/EPL'

# %%
urlopen(url)

# %%
pageconnect = urlopen(url)
pageconnect

# %%
page_html = BeautifulSoup(pageconnect, "html.parser")
page_html
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <base href="https://understat.com/"/>
# <title>EPL xG Table and Scorers for the 2020/2021 season | Understat.com</title>
# <meta charset="utf-8"/>
# <meta content="xG table of EPL standings and top scorers for the 2020/2021 season, also tables from past seasons and other European football leagues." name="description"/>
# <meta content="EPL, xg table,scorers, expected goals table, season 2020/2021" name="Keywords"/>
# <link href="apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="understat" name="apple-mobile-web-app-title"/>
# <meta content="understat" name="application-name"/>
# <meta content="#ffffff" name="theme-color"/>
# ...

# %%
page_html.findAll("script")[3]
# Out:
# <script>
# ...

# %%
json_raw_string = page_html.findAll('script')[3].text

# %%
json_raw_string
# Out:
# "\n\tvar playersData\t= JSON.parse('\\x5B\\x7B\\x22id\\x22\\x3A\\x22647\\x22,\\x22player_name\\x22\\x3A\\x22Harry\\x20Kane\\x22,\\x22games\\x22\\x3A\\x2235\\x22,\\x22time\\x22\\x3A\\x223097\\x22,\\x22goals\\x22\\x3A\\x2223\\x22,\\x22xG\\x22\\x3A\\x2222.174858909100294\\x22,\\x22assists\\x22\\x3A\\x2214\\x22,\\x22xA\\x22\\x3A\\x227.577093588188291\\x22,\\x22shots\\x22\\x3A\\x22138\\x22,\\x22key_passes\\x22\\x3A\\x2249\\x22,\\x22yellow_cards\\x22\\x3A\\x221\\x22,\\x22red_cards\\x22\\x3A\\x220\\x22,\\x22position\\x22\\x3A\\x22F\\x22,\\x22team_title\\x22\\x3A\\x22Tottenham\\x22,\\x22npg\\x22\\x3A\\x2219\\x22,\\x22npxG\\x22\\x3A\\x2219.130183439701796\\x22,\\x22xGChain\\x22\\x3A\\x2224.995648321695626\\x22,\\x22xGBuildup\\x22\\x3A\\x224.451256847940385\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x221250\\x22,\\x22player_name\\x22\\x3A\\x22Mohamed\\x20Salah\\x22,\\x22games\\x22\\x3A\\x2237\\x22,\\x22time\\x22\\x3A\\x223085\\x22,\\x22goals\\x22\\x3A\\x2222\\x22,\\x22xG\\x22\\x3A\\x2220.25084663741290
# ...

# %%
istart = json_raw_string.index("(")+2
iend = json_raw_string.index("')")

# %%
istart
# Out:
# 32

# %%
iend
# Out:
# 331066

# %%
json_raw_string = json_raw_string[istart:iend]
json_raw_string
# Out:
# '\\x5B\\x7B\\x22id\\x22\\x3A\\x22647\\x22,\\x22player_name\\x22\\x3A\\x22Harry\\x20Kane\\x22,\\x22games\\x22\\x3A\\x2235\\x22,\\x22time\\x22\\x3A\\x223097\\x22,\\x22goals\\x22\\x3A\\x2223\\x22,\\x22xG\\x22\\x3A\\x2222.174858909100294\\x22,\\x22assists\\x22\\x3A\\x2214\\x22,\\x22xA\\x22\\x3A\\x227.577093588188291\\x22,\\x22shots\\x22\\x3A\\x22138\\x22,\\x22key_passes\\x22\\x3A\\x2249\\x22,\\x22yellow_cards\\x22\\x3A\\x221\\x22,\\x22red_cards\\x22\\x3A\\x220\\x22,\\x22position\\x22\\x3A\\x22F\\x22,\\x22team_title\\x22\\x3A\\x22Tottenham\\x22,\\x22npg\\x22\\x3A\\x2219\\x22,\\x22npxG\\x22\\x3A\\x2219.130183439701796\\x22,\\x22xGChain\\x22\\x3A\\x2224.995648321695626\\x22,\\x22xGBuildup\\x22\\x3A\\x224.451256847940385\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x221250\\x22,\\x22player_name\\x22\\x3A\\x22Mohamed\\x20Salah\\x22,\\x22games\\x22\\x3A\\x2237\\x22,\\x22time\\x22\\x3A\\x223085\\x22,\\x22goals\\x22\\x3A\\x2222\\x22,\\x22xG\\x22\\x3A\\x2220.250846637412906\\x22,\\x22assists\\x22\\x3A\\x225
# ...

# %%
json_data = json_raw_string.encode("utf-8").decode("unicode escape")
json_data
# Out:
# '[{"id":"647","player_name":"Harry Kane","games":"35","time":"3097","goals":"23","xG":"22.174858909100294","assists":"14","xA":"7.577093588188291","shots":"138","key_passes":"49","yellow_cards":"1","red_cards":"0","position":"F","team_title":"Tottenham","npg":"19","npxG":"19.130183439701796","xGChain":"24.995648321695626","xGBuildup":"4.451256847940385"},{"id":"1250","player_name":"Mohamed Salah","games":"37","time":"3085","goals":"22","xG":"20.250846637412906","assists":"5","xA":"6.528526101261377","shots":"126","key_passes":"55","yellow_cards":"0","red_cards":"0","position":"F M S","team_title":"Liverpool","npg":"16","npxG":"15.683833638206124","xGChain":"28.968233548104763","xGBuildup":"9.800235655158758"},{"id":"1228","player_name":"Bruno Fernandes","games":"37","time":"3117","goals":"18","xG":"16.0194544615224","assists":"12","xA":"11.474995978176594","shots":"121","key_passes":"95","yellow_cards":"6","red_cards":"0","position":"M S","team_title":"Manchester United","npg":"9","n
# ...

# %%
json.loads(json_data).__len__()
# Out:
# 524

# %%
df_EPL = pd.json_normalize(json.loads(json_data))

# %%
df_EPL
# Out:
#        id      player_name  ...             xGChain           xGBuildup
# 0     647       Harry Kane  ...  24.995648321695626   4.451256847940385
# 1    1250    Mohamed Salah  ...  28.968233548104763   9.800235655158758
# 2    1228  Bruno Fernandes  ...  26.911412378773093   11.93228487111628
# 3     453    Son Heung-Min  ...    20.6719155497849   6.608751138672233
# 4     822  Patrick Bamford  ...  23.394952706992626   4.131795546039939
# ..    ...              ...  ...                 ...                 ...
# 519  9423  Gaetano Berardi  ...  0.2312779352068901  0.2312779352068901
# 520  9540      Femi Seriki  ...                   0                   0
# 521  9552  Tyrese Francois  ...                   0                   0
# 522  9557     William Fish  ...                   0                   0
# 523  9558  Hannibal Mejbri  ...                   0                   0
#
# [524 rows x 18 columns]

# %%
print(df_EPL.columns)
# Out:
# Index(['id', 'player_name', 'games', 'time', 'goals', 'xG', 'assists', 'xA',
#        'shots', 'key_passes', 'yellow_cards', 'red_cards', 'position',
#        'team_title', 'npg', 'npxG', 'xGChain', 'xGBuildup'],
#       dtype='object')

# %%
S1 = input("Enter Striker 1: ")
S2 = input("Enter Striker 2: ")
# Out:
# Enter Striker 1: Harry Kane
# Enter Striker 2: Mohamed Salah

# %%
df = df_EPL[(df_EPL['player_name'] == S1) | (df_EPL['player_name'] == S2)]
df
# Out:
#      id    player_name  ...             xGChain          xGBuildup
# 0   647     Harry Kane  ...  24.995648321695626  4.451256847940385
# 1  1250  Mohamed Salah  ...  28.968233548104763  9.800235655158758
#
# [2 rows x 18 columns]

# %%
df_params = df[['goals','assists','shots','xG','xA','npg','npxG','xGChain','xGBuildup']]
df_params = df_params.astype(float)
df_params
# Out:
#    goals  assists  shots         xG  ...   npg       npxG    xGChain  xGBuildup
# 0   23.0     14.0  138.0  22.174859  ...  19.0  19.130183  24.995648   4.451257
# 1   22.0      5.0  126.0  20.250847  ...  16.0  15.683834  28.968234   9.800236
#
# [2 rows x 9 columns]

# %%
#get parameters
params = list(df_params.columns)
params
# Out:
# ['goals',
#  'assists',
#  'shots',
#  'xG',
#  'xA',
#  'npg',
#  'npxG',
#  'xGChain',
#  'xGBuildup']

# %%
#Add ranges to list of tuple pairs
ranges = []
a_values = []
b_values = []

for x in params:
  a = min(df_params[params][x])
  a = 0.75*a
  
  b = max(df_params[params][x])
  b = 1.25*b

  ranges.append((a,b))

for i,x in df_params.iterrows():
  if df['player_name'][i] == S1:
    a_values = df_params.loc[i].values.tolist()
  if df['player_name'][i] == S2:
    b_values = df_params.loc[i].values.tolist() 
values = [a_values, b_values]

# %%
a_values
# Out:
# [23.0,
#  14.0,
#  138.0,
#  22.174858909100294,
#  7.577093588188291,
#  19.0,
#  19.130183439701796,
#  24.995648321695626,
#  4.451256847940385]

# %%
b_values
# Out:
# [22.0,
#  5.0,
#  126.0,
#  20.250846637412906,
#  6.528526101261377,
#  16.0,
#  15.683833638206124,
#  28.968233548104763,
#  9.800235655158758]

# %%
ranges
# Out:
# [(16.5, 28.75),
#  (3.75, 17.5),
#  (94.5, 172.5),
#  (15.18813497805968, 27.718573636375368),
#  (4.896394575946033, 9.471366985235363),
#  (12.0, 23.75),
#  (11.762875228654593, 23.912729299627244),
#  (18.74673624127172, 36.210291935130954),
#  (3.338442635955289, 12.250294568948448)]

# %%
values
# Out:
# [[23.0,
#   14.0,
#   138.0,
#   22.174858909100294,
#   7.577093588188291,
#   19.0,
#   19.130183439701796,
#   24.995648321695626,
#   4.451256847940385],
#  [22.0,
#   5.0,
#   126.0,
#   20.250846637412906,
#   6.528526101261377,
#   16.0,
#   15.683833638206124,
#   28.968233548104763,
#   9.800235655158758]]

# %%
import matplotlib.pyplot as plt
from soccerplots.radar_chart import Radar

#title

title = dict(
    title_name = S1,
    title_color = '#9B3647',
    subtitle_name = 'Tottenham Hotspur',
    subtitle_color = '#9B3647',
    title_name_2 = S2,
    title_color_2 = '#3282b8',
    subtitle_name_2 = 'Liverpool',
    subtitle_color_2 = '#3282b8',
    title_fontsize = 18,
    subtitle_fontsize = 15
)

endnote = '@NTripathii \nData from Understat.com'
radar = Radar(label_fontsize= 14, range_fontsize= 10, background_color="#121212", patch_color="#28252C", label_color="#F0FFF0",
              range_color="#F0FFF0")
fig,ax = radar.plot_radar(ranges =  ranges, params = params, values = values,
                          radar_color = ['#9B3647', '#3282b8'], 
                          alphas = [0.8,0.6], title = title, endnote = endnote,
                          end_size = 11.3, compare = True)
